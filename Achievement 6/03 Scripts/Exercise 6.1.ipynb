# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path  = r'C:\Users\Layzr\Desktop\School\Data Immersion Part 6'

# %%
df = pd.read_csv(os.path.join(path, 'Data', 'achievement_6_dataset.csv'), encoding='latin1')

# %%
df.shape
# Out:
# (1999, 35)

# %%
df.head(10)
# Out:
#    Year            Player  Age Team  Lg  WAR    G   PA   AB    R  ...  Rbat+  \
# 0  2023     Marcus Semien   32  TEX  AL  7.7  162  753  670  122  ...    131
# 1  2023  Ronald Acuña Jr.   25  ATL  NL  8.4  159  735  643  149  ...    175
# 2  2024     Jarren Duran*   27  BOS  AL  8.7  160  735  671  111  ...    134
# 3  2024    Shohei Ohtani*   29  LAD  NL  9.2  159  731  636  134  ...    190
# 4  2023  Freddie Freeman*   33  LAD  NL  6.8  161  730  637  131  ...    167
# 5  2023      Alex Bregman   29  HOU  AL  4.9  161  724  622  103  ...    124
# 6  2023   Nathaniel Lowe*   27  TEX  AL  2.9  161  724  623   89  ...    117
# 7  2022     Marcus Semien   31  TEX  AL  5.7  161  724  657  101  ...    111
# 8  2023   Kyle Schwarber*   30  PHI  NL  0.7  160  720  585  108  ...    119
# 9  2023       Matt Olson*   29  ATL  NL  7.5  162  720  608  127  ...    163
#
#     TB  GIDP  HBP  SH  SF  IBB   Pos     Awards  Player-additional
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               1999 non-null   int64
#  1   Player             1999 non-null   object
#  2   Age                1999 non-null   int64
#  3   Team               1999 non-null   object
#  4   Lg                 1999 non-null   object
#  5   WAR                1994 non-null   float64
#  6   G                  1999 non-null   int64
#  7   PA                 1999 non-null   int64
#  8   AB                 1999 non-null   int64
#  9   R                  1999 non-null   int64
#  10  H                  1999 non-null   int64
#  11  2B                 1999 non-null   int64
#  12  3B                 1999 non-null   int64
#  13  HR                 1999 non-null   int64
#  14  RBI                1999 non-null   int64
#  15  SB                 1999 non-null   int64
# ...

# %%
df = df.drop_duplicates()

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
df['year'] = df['year'].astype('string')

# %%
df['pos'] = df['pos'].astype('string')

# %%
df['awards'] = df['awards'].astype('string')

# %%
df['player-additional'] = df['player-additional'].astype('string')

# %%
df.dtypes
# Out:
# year                 string[python]
# player                       object
# age                           int64
# team                         object
# lg                           object
# war                         float64
# g                             int64
# pa                            int64
# ab                            int64
# r                             int64
# h                             int64
# 2b                            int64
# 3b                            int64
# hr                            int64
# rbi                           int64
# sb                            int64
# cs                            int64
# bb                            int64
# so                            int64
# ba                          float64
# obp                         float64
# slg                         float64
# ops                         float64
# ops+                          int64
# roba                        float64
# rbat+                         int64
# ...

# %%
print(df.describe())
# Out:
#                age          war            g           pa           ab  \
# count  1999.000000  1994.000000  1999.000000  1999.000000  1999.000000
# mean     27.728864     0.889468    75.728864   274.439220   245.907954
# std       3.676008     1.704944    51.112983   215.304617   192.135154
# min      19.000000    -2.100000     1.000000     1.000000     1.000000
# 25%      25.000000    -0.200000    27.000000    73.000000    66.000000
# 50%      27.000000     0.300000    73.000000   237.000000   213.000000
# 75%      30.000000     1.575000   123.000000   451.000000   403.000000
# max      42.000000    10.800000   162.000000   753.000000   671.000000
#
#                  r            h           2b           3b           hr  ...  \
# count  1999.000000  1999.000000  1999.000000  1999.000000  1999.000000  ...
# mean     32.310655    60.198599    11.975488     1.026513     8.272136  ...
# std      28.788223    51.536279    10.926815     1.610090     9.280577  ...
# ...

# %%
df.to_csv(os.path.join(path, 'Data', 'cleaned_dataset.csv'))
